# %% [markdown]
# # Descriptive overview and preprocessing of the dataset

# %%
RUTA_prepo = "/Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/"
RUTA_vis = "/Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/report"

# %% [markdown]
# ## MIMIC-III database schema

# %% [markdown]
# Obtained from MIMIC-III Article
#
#
# *input*:  not applied
#
# *output*:  not applied

# %% [markdown]
# ##  Entity relationship diagram

# %% [markdown]
# Obtained from Mino website
#
#
# *input*:  not applied
#
# *output*:  not applied

# %% [markdown]
# ## Demographics and admission variables

# %% [markdown]
# ### Figure pie charts
#
# **input**:  MIMIC / 'ADMISSIONS.csv.gz' /DARTA_INTERM/ 'data_preprocess_non_filtered.csv'
#
#  **output**: IMAGES_Demo+'demo_pie.svg'

# %%
# %cd /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/report
# %run vis_.py "demo_pie"
# Out:
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/report
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# Directorio actual: /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# La ruta existe.
# 7537

# %% [markdown]
# ###  Distribution of counts of ICD-9 ['procedures', 'diagnosis', 'medicament']
#
# **input**:  DARTA_INTERM/"choices_preprocess_threshold_nonfiltered.csv"  choices=['procedures', 'diagnosis', 'medicament']
#
#  **output**:IMAGES_Demo + 'counts_10.svg' /IMAGES_Demo + 'histograms_patient.svg'

# %%
# %cd /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/report
# %run vis_.py "countpr_admi_patient" --type_procedur procedures
# Out:
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/report
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# Directorio actual: /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# La ruta existe.

# %% [markdown]
# ###  10 most frequent Procedures, Diagnosis and Medicament
#
# **input**:   DARTA_INTERM/"choices_preprocess_threshold_nonfiltered.csv"
#
#  **output**: IMAGES_Demo + 'counts_10.svg' /IMAGES_Demo + 'histograns_patient.svg'

# %%
# %cd /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/report
# %run vis_.py "10_most_frequent" --type_procedur procedures
# Out:
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/report
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# Directorio actual: /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# La ruta existe.

# %% [markdown]
# ###  Kernel density plot, age and lengh of stay
#
# **input**:  nput_model_pred / 'ICD9_CODE_procedures_outs_visit_non_filtered.csv'
#
#  **output**: DATA_DEMOS /" LOS_KERNELPLOT.svg"

# %%
# %cd {RUTA_vis}
# %run vis_.py "Kernel_density_estimation"
# Out:
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/report
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# Directorio actual: /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# La ruta existe.
# Male      23405
# Female    17611
# Name: GENDER, dtype: int64

# %% [markdown]
# ###  Histogram of thresholds procedures
#
# **input**:  list IC9-codes, num_bins, threshold_value, cat is the name of plot
#
#  **output**: IMAGES_Demo+'thresholds_+'+threshold_value+'.svg'

# %%
from preprocess_input1 import  cumulative_plot

cumulative_plot(icd9_codes, num_bins,threshold_value,cat)

# %% [markdown]
# # 2.3 Method

# %% [markdown]
# ## 2.3.1 Preprocessing the input for Synthetic Data

# %% [markdown]
# ###  Data cleaning
#
# Table:
# Number of NAns per [drugs, procedures,diagnosis] and  N° of Patient and Admission negative Length of Stay (LOS)
#
# **input**:  input:  raw data /ADMISSIONS.csv.gz /PROCEDUREs.csv.gz /DIAGNOSES_ICD.csv.gz
#
#  **output**: output: clean data

# %%
# %cd {RUTA_prepo+'preprocessing'}
from preprocess_class1 import DataPreprocessor
from config import *

type_p = "procedures" # aplica para diagnosis y medicament
name="ICD9_CODE"
prepomax = 'std'
real = "CCS CODES"
level = "Otro"
admissions_path = '..'/MIMIC/'ADMISSIONS.csv.gz'
patients_path = '..'/MIMIC /'PATIENTS.csv.gz'
numerical_cols =  ['Age_max', 'LOSRD_sum',
        'LOSRD_avg','L_1s_last_p1']
doc_path = '..'/MIMIC/'PROCEDURES_ICD.csv.gz'
    
n = [.88]
categorical_cols = ['ADMISSION_TYPE', 'ADMISSION_LOCATION',
                'DISCHARGE_LOCATION', 'INSURANCE',  'RELIGION',
                'MARITAL_STATUS',  'ETHNICITY','GENDER']


preprocessor = DataPreprocessor(type_p,doc_path, admissions_path, patients_path, categorical_cols, real, level, numerical_cols, prepomax,name,n, cols_to = None,normalize_matrix=False, log_transformation=False, encode_categorical=False, final_preprocessing=True,proportion = True,prop = 0.09)   
type_p = ['procedures', 'diagnosis', 'medicament']
data = preprocessor.load_data_clean_data(type_p[0])
# Out:
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/preprocessing
# uniqueHADM_ID 52243
# uniqueSUBJECT_ID 42214
# uniqueICD9_CODE 2009
# Númber of null values after obtaining individual values of ICD9-CODES :  HADM_ID       0
# SUBJECT_ID    0
# ICD9_CODE     0
# dtype: int64
# uniqueHADM_ID 52243
# uniqueSUBJECT_ID 42214
# uniqueICD9_CODE 2009
# Númber of null values dropna :  HADM_ID       0
# SUBJECT_ID    0
# ICD9_CODE     0
# dtype: int64
# Shape df :  (240095, 3)
# Númber of null values after obtaining CCS codes and Level 3 HADM_ID            0
# SUBJECT_ID         0
# ICD9_CODE          0
# LEVE3 CODES        0
# CCS CODES      12422
# dtype: int64
# nuevo_df :  (240095, 5)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/xn/hrsr6_j92psb5bqf9kjzwv8w0000gp/T/ipykernel_13777/1038873570.py in <module>
# ...

# %% [markdown]
# ###  Preparing the input for the generation of synthetic data
# Done manually with Mimo
# **input**:  does not apply
#
#  **output**: does not apply

# %%
### Demographics and Admission Variables .

###input:  adm = ADMISSIONS.csv.gz / pa = PATIENTS.csv.gz / categorical_cols = ['INSURANCE', 'LANGUAGE', 'RELIGION', 'MARITAL'..] 
#/level = [Patiemnt, Admission] /cat_considered =     categorical_cols = ['ADMISSION_TYPE', 'ADMISSION_LOCATION',
# 'DISCHARGE_LOCATION', 'INSURANCE',  'RELIGION', 'MARITAL_STATUS',  'ETHNICITY','GENDER']
# cat_considered = ['ADMITTIME', 'ADMISSION_TYPE', 'ADMISSION_LOCATION', 'DISCHARGE_LOCATION', 'INSURANCE', 'RELIGION', 'MARITAL_STATUS', 'ETHNICITY', 'DEATHTIME'] + ['DISCHTIME', 'SUBJECT_ID', 'HADM_ID']
###output: demographics dataframe
# %cd {RUTA_prepo+'preprocessing'}
from preprocess_class1 import calculate_demographics
adm = '..'/MIMIC/'ADMISSIONS.csv.gz'
pa =  '..'/MIMIC/'PATIENTS.csv.gz'
categorical_cols = ['ADMISSION_TYPE', 'ADMISSION_LOCATION',
 'DISCHARGE_LOCATION', 'INSURANCE',  'RELIGION', 'MARITAL_STATUS',  'ETHNICITY','GENDER']
level= "visit"
cat_considered = ['ADMITTIME', 'ADMISSION_TYPE', 'ADMISSION_LOCATION', 'DISCHARGE_LOCATION', 'INSURANCE', 'RELIGION', 'MARITAL_STATUS', 'ETHNICITY', 'DEATHTIME'] + ['DISCHTIME' ]

demos = calculate_demographics(adm,pa, categorical_cols, level,cat_considered,prod_ipvot=None)
#
# Out:
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/preprocessing
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/preprocessing/preprocess_input1.py:696: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aux_ad["SUBJECT_ID"] = aux_ad["SUBJECT_ID"].astype(str)
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/preprocessing/preprocess_input1.py:697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ### CCS c/ thresholds simplifications procedures
# #### map ccs codes to ICD-9 codes
# **input**:  data/raw/ PROCEDURE_ICD.csv.gz
# **output**:CCS codes , thresholds

# %%
# %cd {RUTA_prepo+'preprocessing'}
from preprocess_input1 import procedures2
from config import *
d2 = '..'/MIMIC/'PROCEDURES_ICD.csv.gz'
n  = [0.88] #thresholds
name = "ICD9_CODE"
procedures2(d2,n,name)
3

# %% [markdown]
# ### CCS codes / Level 3 /  thresholds simplifications Diagnosis
# #### map ccs codes to ICD-9 codes
# **input**: archivo DIAGNOSIS. thresholds, name ICD9, codes
# **output**: Diagnosis desconcatenados por admission id, mapeadmos ccs codes level 3, y simplifications

# %%
# %cd {RUTA_prepo+'preprocessing'}
from preprocess_input1 import diagnosis2
from config import *
d2 = '..'/MIMIC/'DIAGNOSES_ICD.csv.gz'
n  = [0.88] #thresholds
name = "ICD9_CODE"
diagnosis2(d2,n,name)
# Out:
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/preprocessing
# Initial df shape with out desconcatenate:  (651047, 5)
# uniqueHADM_ID 58976
# uniqueSUBJECT_ID 46520
# uniqueICD9_CODE 6984
#        HADM_ID SUBJECT_ID ICD9_CODE
# 0       172335        109     40301
# 1       172335        109       486
# 2       172335        109     58281
# 3       172335        109      5855
# 4       172335        109      4254
# ...        ...        ...       ...
# 651042  188195      97503     20280
# 651043  188195      97503     V5869
# 651044  188195      97503     V1279
# 651045  188195      97503      5275
# 651046  188195      97503      5569
#
# [651047 rows x 3 columns]
#         SUBJECT_ID HADM_ID ICD9_CODE
# 0              109  172335         4
# 1              109  172335         0
# 2              109  172335         3
# 3              109  172335         0
# 4              109  172335         1
# ...            ...     ...       ...
# ...

# %% [markdown]
# ### ATC3, ATC4 Drugs
#
# **input**:  archivo raw drugs  MIMIC/'PRESCRIPTIONS.csv.gz'
#
#  **output**: drugs mapped a atc3 y atc4

# %%
# %cd {RUTA_prepo+'preprocessing'}
from preprocess_input1 import drug2
from config import *
d2 = '..'/MIMIC/'PRESCRIPTIONS.csv.gz'

drug2(d2)
# Out:
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/preprocessing
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/preprocessing/preprocess_input1.py:65: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   med_pd = pd.read_csv(med_file, dtype={"NDC": "category"})
# med_pd initial shape :  (3416228, 5)
# uniqueSUBJECT_ID 39087
# uniqueHADM_ID 49929
# uniqueSTARTDATE 38265
# uniqueDRUG 2541
# uniqueNDC 2929
# uniqueRXCUI 2037
# uniqueATC4 348
# uniqueATC3 155
# med_pd after atc3 shape :  (1452205, 8)
# med_p values after mapping  SUBJECT_ID    0
# HADM_ID       0
# STARTDATE     0
# DRUG          0
# NDC           0
# RXCUI         0
# ATC4          0
# ATC3          0
# dtype: int64
# med_pd initial shape:  SUBJECT_ID    0
# HADM_ID       0
# STARTDATE     0
# DRUG          0
# NDC           0
# RXCUI         0
# ATC4          0
# ATC3          0
# dtype: int64
# ...

# %% [markdown]
# ## 2.3.2 Preprocessing the input for Clustering and predictions algorithms
# ### Data transformation.

# %% [markdown]
# **input**: --normalize_matrix True --log_transformation True --encode_categorical True,
#
# opcionales [drugs,diagnosis ,procedures]
#
# **output**: matriz de conteos de cualquier de las 3 opciones y concatenados con las variables demograficas, standarizadas

# %%
import os

os.chdir(RUTA_prepo ')
import sys
sys.path.append(RUTA_prepo )
# %run preprocessing//preprocess_class1.py diagnosis --normalize_matrix --log_transformation --encode_categorical
# Out:
# La ruta no existe.
# Process: diagnosis
# Standard matriz: True
# Logarithmic transformation: True
# Codify categorical variables: True
# Initial df shape with out desconcatenate:  (651047, 5)
# uniqueHADM_ID 58976
# uniqueSUBJECT_ID 46520
# uniqueICD9_CODE 6984
#        HADM_ID SUBJECT_ID ICD9_CODE
# 0       172335        109     40301
# 1       172335        109       486
# 2       172335        109     58281
# 3       172335        109      5855
# 4       172335        109      4254
# ...        ...        ...       ...
# 651042  188195      97503     20280
# 651043  188195      97503     V5869
# 651044  188195      97503     V1279
# 651045  188195      97503      5275
# 651046  188195      97503      5569
#
# [651047 rows x 3 columns]
#         SUBJECT_ID HADM_ID ICD9_CODE
# 0              109  172335         4
# 1              109  172335         0
# 2              109  172335         3
# 3              109  172335         0
# 4              109  172335         1
# ...

# %% [markdown]
# ### Preprocessing for classification and clustering
# Mino website
#
# diagram
# **input**: not aplicable
#
# **output**: not aplicable

# %% [markdown]
# # 2.4 Results
#
# ###  Simplification of ICD-9 procedure codes without considering demographics and
# admission variables.

# %% [markdown]
# ###
#
# **input**:  input preprocessed data, data_preprocess_non_filtered.csv
#
#  **output**: image pacmap representation

# %%
# %cd {RUTA_vis}

# %run vis_.py "pacmap_representation"
# Out:
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/report
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# Directorio actual: /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# La ruta existe.
# ['sin_codigo.csv', 'cat_threshold .88 most frequent_outs_visit_non_filtered.csv', 'cat_threshold .95 most frequent_proc_outs_visit_non_filtered.csv', 'cat_threshold .999 most frequent_outs_visit_non_filtered.csv', 'cat_threshold .98 most frequent_outs_visit_non_filtered.csv', 'CCS CODES_proc_outs_visit_non_filtered.csv', 'ICD9_CODE_procedures_outs_visit_non_filtered.csv']
# sin_codigo.csv
# cat_threshold .88 most frequent_outs_visit_non_filtered.csv
# cat_threshold .95 most frequent_proc_outs_visit_non_filtered.csv
# cat_threshold .999 most frequent_outs_visit_non_filtered.csv
# cat_threshold .98 most frequent_outs_visit_non_filtered.csv
# CCS CODES_proc_outs_visit_non_filtered.csv
# ...

# %% [markdown]
# ## Clustering

# %% [markdown]
# **input**:  input for preprocesing, level, patient /visit
#
#  **output**:"models_cluster/ sihouette and rand score

# %%
# %cd {RUTA_prepo+'preprocessing/scrypt'} 
% run metricas_cluter_script.py

# %% [markdown]
# ## Silhouette Scores by preprocessing type and number cluster
#
# Figures for the Silhouette Scores by preprocessing type and number cluster diagnosis, drugs procedures

# %% [markdown]
# ###
#
# **input**:  sihouette and rand score from 3 types
#
#  **output**:IMAGES_Cluster_DICT+'real_Preprocessing'+level+'_'+str(i)+'.svg'

# %%
# %cd {RUTA_prepo+'report'}

# %run vis_.py "preprocessing_clustering_exp"
# Out:
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/report
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# Directorio actual: /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# La ruta existe.

# %% [markdown]
# ## Clustering Consistency
#
# ## mutual information experiment

# %% [markdown]
# **input**:  clusteringf  results, input_model_pred/ clustering results
#
#  **output**:./models_cluster/mi_"+u+"patient_m.csv"  mutual infomation metric and rand score for each simplification, patien and visit level

# %%
# %cd {RUTA_prepo+'preprocessing/scrypt'} 
% run mutual_information_script.py

# %% [markdown]
# ### Figure heatmap rand index, patient and visit level

# %% [markdown]
# ###
#
# **input**:  mutual information results
#
#  **output**: IMAGES_Cluster_DICT+type_in+'_mutual_information.svg'

# %%
# %cd {RUTA_prepo+'report'}

# %run vis_.py "get_mutula_information"
# Out:
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning/report
# /Users/cgarciay/opt/anaconda3/envs/luigi/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# Directorio actual: /Users/cgarciay/Desktop/Laval_Master_Computer/research/Synthetic-Data-Deep-Learning
# La ruta existe.

# %% [markdown]
# ## Prediction of 30 days readmission
# ##

# %% [markdown]
# ###
#
# **input**:  Preprocessed input
#
#  **output**: results are stored in wandb

# %%
# %cd {RUTA_prepo+'preprocessing/scrypt'} 
% run function_pred.py

# %% [markdown]
# ###  Performance predictions (readmission)
#
# **input**: results_pred/ wandb results, types [diagnosis,procedures,drugs]
#
#  **output*

# %%
# %cd {RUTA_prepo+'report'
# %run vis_.py "Readmission_drugs"

# %% [markdown]
# ###  Hyperparameter tunining
#
# **input**:input of prediction , change for logistic_regresion or xgboost in coninput_json
#
#  **output* best hyperparameters

# %%
# %cd {RUTA_prepo+'preprocessing/scrypt'} 
% run readmission_pred_script_wandb2.py.py

# %% [markdown]
# ###  Hyperparameter tables
#
# **input**:  wandb data, stores in results, and pas tesult predictions
#
#  **output**:

# %%
# %cd {RUTA_prepo+'report'}

# %run vis_.py "hyperparameter_drugs"

# %% [markdown]
# ###
#
# **input**:
#
#  **output**:

# %% [markdown]
# ###
#
# **input**:
#
#  **output**:

# %% [markdown]
# ###
#
# **input**:
#
#  **output**:

# %% [markdown]
# ###
#
# **input**:
#
#  **output**:

# %% [markdown]
# ###
#
# **input**:
#
#  **output**:

# %% [markdown]
# ###
#
# **input**:
#
#  **output**:

# %% [markdown]
# ###
#
# **input**:
#
#  **output**:

# %% [markdown]
# ###
#
# **input**:
#
#  **output**:

# %% [markdown]
# ###
#
# **input**:
#
#  **output**:
